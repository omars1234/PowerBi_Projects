# %%
# This is a Python cell
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
<div>njnjnjn</div>,
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
#    <div>
#     njnjnjn
#    </div>
#    ,
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# "The Dormouse's story"

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
for child in soup.p.children:
    print(child)


print("---"*40)
# Out:
# <b>The Dormouse's story</b>
# ------------------------------------------------------------------------------------------------------------------------

# %%
# Out:
# []

# %%
 
import re
soup.find_all(re.compile("[ou]l"))
print("---"*40)   
soup.find_all(re.compile("[1-9]"))
print("---"*40)   
soup.find_all(['h1', 'a', 'p'])
print("---"*40)   
#soup.find_all(attrs={'class':'banner', 'id':'jum‐botron'});
print("---"*40)   
#def has_banner_class_and_hello_world( tag):
#    return tag.attr('class') == "banner" and tag.string == "Hello world"
#soup.find_all(has_banner_class_and_hello_world)
# Out:
# []
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------

# %%
soup.find_all(['h1', 'a', 'p'])
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  <div>njnjnjn</div>,
#  and they lived at the bottom of a well.</p>,
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>,
#  <p class="story">...</p>]

# %%
print(soup.div.name)
print(soup.div.attrs)
print(soup.div.string)
# Out:
# div
# {}
# njnjnjn

# %%
soup.p.parent
# Out:
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body>

# %%
soup.p["class"]
# Out:
# ['title']

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
print(soup.get_text())
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %% [markdown]
# ---

# %%
example="""
<h1>World's Best Chocolate Chip Cookies</h1>
<div class="banner">
  <h1>Ingredients</h1>
</div>
<ul>
  <li> 1 cup flour </li>
  <li> 1/2 cup sugar </li>
  <li> 2 tbsp oil </li>
  <li> 1/2 tsp baking soda </li>
  <li> ½ cup chocolate chips </li> 
  <li> 1/2 tsp vanilla <li>
  <li> 2 tbsp milk </li>
</ul>
"""

# %%
from bs4 import BeautifulSoup
import requests
url = example

# %%
for child in soup.ul.children:
    print(child)
# Out:
# <li><style data-emotion="css 146l34e">.css-146l34e{--color:var(--anonymous-nav-link-color);--padding:1rem 1.25rem;display:block;padding:var(--padding);color:var(--color);font-size:var(--anonymous-nav-link-font-size);letter-spacing:0.02em;line-height:1;-webkit-text-decoration:none;text-decoration:none;}@media (hover: hover){.css-146l34e:hover{-webkit-text-decoration:underline;text-decoration:underline;}}@media (min-width: 600px){.css-146l34e{--color:var(--anonymous-nav-cta-color);--padding:0;font-weight:600;text-transform:uppercase;}}@media (min-width: 600px) and (hover: hover){.css-146l34e{border-bottom:2px solid transparent;}.css-146l34e:hover{color:var(--color);border-bottom:2px solid var(--anonymous-nav-cta-color);-webkit-text-decoration:none;text-decoration:none;}}</style><a class="css-146l34e" href="https://www.oreilly.com/member/login/">Sign In</a></li>
# ...

# %%
[link for link in soup.find_all('link')]
# Out:
# [<link crossorigin="" href="https://cdn.oreillystatic.com" rel="preconnect"/>,
#  <link as="font" crossorigin='"anonymous"' href="https://cdn.oreillystatic.com/fonts/Gilroy/Family/gilroy-bold.woff2" rel="preload" type="font/woff2"/>,
#  <link as="font" crossorigin='"anonymous"' href="https://cdn.oreillystatic.com/fonts/Gilroy/Family/gilroy-regular.woff2" rel="preload" type="font/woff2"/>,
#  <link as="font" crossorigin='"anonymous"' href="https://cdn.oreillystatic.com/fonts/Gilroy/Family/gilroy-medium.woff2" rel="preload" type="font/woff2"/>,
#  <link as="font" crossorigin='"anonymous"' href="https://cdn.oreillystatic.com/fonts/Gilroy/Family/gilroy-semibold.woff2" rel="preload" type="font/woff2"/>,
#  <link as="font" crossorigin='"anonymous"' href="https://cdn.oreillystatic.com/fonts/GuardianText/GuardianTextSans-Medium-Web.woff2" rel="preload" type="font/woff2"/>,
# ...

# %%
[div for div in soup.find_all('div')]
# Out:
# [<div id="root"><a class="orm-ff-AnonymousShell-skipLink" href="#main">Skip to content</a><style data-emotion="css o0aqtq">.css-o0aqtq{--anonymous-header-submenu-bg:rgba(247, 247, 247, 0.98);--anonymous-header-transition:150ms ease-in-out;--anonymous-nav-cta-color:#0071eb;--anonymous-nav-link-color:#222;--anonymous-nav-link-font-size:0.875rem;--block-padding:1rem;position:-webkit-sticky;position:sticky;top:0;z-index:9;padding-block:var(--block-padding);font-family:var(--anonymous-font);-webkit-backdrop-filter:saturate(200%) blur(16px);backdrop-filter:saturate(200%) blur(16px);background-color:rgba(255, 255, 255, 0.95);border-bottom:1px solid rgba(0, 0, 0, 0.1);box-sizing:border-box;}.css-o0aqtq,.css-o0aqtq *,.css-o0aqtq *::before,.css-o0aqtq *::after{box-sizing:border-box;}@media (min-width: 600px){.css-o0aqtq{--block-padding:1.25rem;}}@media (max-width: 1151px){.css-o0aqtq *[class='hide-on-mobile']{display:none;}}@media (min-width: 960px){.css-o0aqtq{--anonymous-nav-link-font-size:0
# ...

# %%
[div for div in soup.div]
# Out:
# [<a class="orm-ff-AnonymousShell-skipLink" href="#main">Skip to content</a>,
# ...

# %%
print(soup.div.name)
print(soup.div.attrs)
print(soup.div.string)
# Out:
# div
# {'id': 'root'}
# None

# %%
soup('div', {'class' : 'css-1rrwnfc'})
# Out:
# [<div class="css-1rrwnfc"><style data-emotion="css u7rrdo animation-c7515d">.css-u7rrdo{display:block;background-color:rgba(48, 47, 42, 0.11);height:1.2em;border-radius:4px;-webkit-animation:animation-c7515d 2s ease-in-out 0.5s infinite;animation:animation-c7515d 2s ease-in-out 0.5s infinite;-webkit-align-self:start;-ms-flex-item-align:start;align-self:start;margin-bottom:1.25rem;}@-webkit-keyframes animation-c7515d{0%{opacity:1;}50%{opacity:0.4;}100%{opacity:1;}}@keyframes animation-c7515d{0%{opacity:1;}50%{opacity:0.4;}100%{opacity:1;}}</style><span class="MuiSkeleton-root MuiSkeleton-rounded MuiSkeleton-pulse css-u7rrdo" style="width:50rem;height:1.125rem"></span><style data-emotion="css 197wjub animation-c7515d">.css-197wjub{display:block;background-color:rgba(48, 47, 42, 0.11);height:1.2em;border-radius:4px;-webkit-animation:animation-c7515d 2s ease-in-out 0.5s infinite;animation:animation-c7515d 2s ease-in-out 0.5s infinite;margin-bottom:0.5rem;}@-webkit-keyframes animation-c75
# ...

# %%
for child in soup.ul.children:
    print(child)
# Out:
# <li><style data-emotion="css 146l34e">.css-146l34e{--color:var(--anonymous-nav-link-color);--padding:1rem 1.25rem;display:block;padding:var(--padding);color:var(--color);font-size:var(--anonymous-nav-link-font-size);letter-spacing:0.02em;line-height:1;-webkit-text-decoration:none;text-decoration:none;}@media (hover: hover){.css-146l34e:hover{-webkit-text-decoration:underline;text-decoration:underline;}}@media (min-width: 600px){.css-146l34e{--color:var(--anonymous-nav-cta-color);--padding:0;font-weight:600;text-transform:uppercase;}}@media (min-width: 600px) and (hover: hover){.css-146l34e{border-bottom:2px solid transparent;}.css-146l34e:hover{color:var(--color);border-bottom:2px solid var(--anonymous-nav-cta-color);-webkit-text-decoration:none;text-decoration:none;}}</style><a class="css-146l34e" href="https://www.oreilly.com/member/login/">Sign In</a></li>
# ...

# %%
for parent in soup.li.parents:
    print(parent)
# Out:
# <ul class="css-1vfbv6f"><li><style data-emotion="css 146l34e">.css-146l34e{--color:var(--anonymous-nav-link-color);--padding:1rem 1.25rem;display:block;padding:var(--padding);color:var(--color);font-size:var(--anonymous-nav-link-font-size);letter-spacing:0.02em;line-height:1;-webkit-text-decoration:none;text-decoration:none;}@media (hover: hover){.css-146l34e:hover{-webkit-text-decoration:underline;text-decoration:underline;}}@media (min-width: 600px){.css-146l34e{--color:var(--anonymous-nav-cta-color);--padding:0;font-weight:600;text-transform:uppercase;}}@media (min-width: 600px) and (hover: hover){.css-146l34e{border-bottom:2px solid transparent;}.css-146l34e:hover{color:var(--color);border-bottom:2px solid var(--anonymous-nav-cta-color);-webkit-text-decoration:none;text-decoration:none;}}</style><a class="css-146l34e" href="https://www.oreilly.com/member/login/">Sign In</a></li><li><style data-emotion="css 34wyzy">.css-34wyzy{--color:var(--anonymous-nav-link-color);--font-size:va
# ...

# %%
print(soup.find_all("h1"))
soup.find_all(['h1', 'a', 'p'])
# Out:
# []
# [<a class="orm-ff-AnonymousShell-skipLink" href="#main">Skip to content</a>,
# ...

# %%
soup.find_all(attrs={'class':'css-1rrwnfc', 'id':'jumbotron'});

# %%
def has_banner_class_and_hello_world(tag):
    return tag.attr('class') == "css-1rrwnfc" and tag.string == "Hello world"

soup.find_all(has_banner_class_and_hello_world)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[218], line 4
#       1 def has_banner_class_and_hello_world(tag):
#       2     return tag.attr('class') == "css-1rrwnfc" and tag.string == "Hello world"
# ----> 4 soup.find_all(has_banner_class_and_hello_world)
#
# File c:\Users\Omar\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\element.py:2035, in Tag.find_all(self, name, attrs, recursive, string, limit, **kwargs)
#    2033     generator = self.children
#    2034 _stacklevel = kwargs.pop('_stacklevel', 2)
# -> 2035 return self._find_all(name, attrs, string, limit, generator,
#    2036                       _stacklevel=_stacklevel+1, **kwargs)
#
# File c:\Users\Omar\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\element.py:841, in PageElement._find_all(self, name, attrs, string, limit, generator, **kwargs)
#     839     break
# ...

# %%
print(soup.title)
# Out:
# <title>Search</title>

# %%
print(soup.find("p"))
# Out:
# <p>Take O'Reilly with you and learn anywhere, anytime on your phone and tablet.</p>

# %%
print(soup.p.text)
# Out:
# Take O'Reilly with you and learn anywhere, anytime on your phone and tablet.

# %%
print(soup.p.text.split())
# Out:
# ['Take', "O'Reilly", 'with', 'you', 'and', 'learn', 'anywhere,', 'anytime', 'on', 'your', 'phone', 'and', 'tablet.']

# %%
print(soup.p.get('id'))
# Out:
# None

# %%
print(soup.find_all('p'))
# Out:
# [<p>Take O'Reilly with you and learn anywhere, anytime on your phone and tablet.</p>, <p>View all O'Reilly videos, Superstream events, and Meet the Expert sessions on your home TV.</p>, <p>© <!-- -->2024<!-- -->, O'Reilly Media, Inc. All trademarks and registered trademarks appearing on oreilly.com are the property of their respective owners.</p>]

# %%
[p for p in soup('p') if p.get('id')] ## id it has ids
# Out:
# []

# %%
soup('span', {'class' : 'css-3kn6vf'})
# Out:
# [<span class="css-3kn6vf"></span>]

# %%
soup.get('tag')

# %%
[span
for div in soup('div') # for each <div> on the page
for span in div('span')]
# Out:
# [<span class="css-3kn6vf"></span>,
# ...

# %%
url='https://beautiful-soup-4.readthedocs.io/en/latest/#name'
print(requests.get(url))
page=requests.get(url)
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.text,'html')

# %%
print(soup.prettify()) #prettify() for hireacchy
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]><html class="no-js lt-ie9" lang="en" > <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Beautiful Soup Documentation — Beautiful Soup 4.4.0 documentation
#   </title>
#   <script src="_static/js/modernizr.min.js" type="text/javascript">
#   </script>
#   <script data-url_root="./" id="documentation_options" src="_static/documentation_options.js" type="text/javascript">
#   </script>
#   <script src="_static/jquery.js" type="text/javascript">
#   </script>
#   <script src="_static/underscore.js" type="text/javascript">
#   </script>
#   <script src="_static/doctools.js" type="text/javascript">
#   </script>
#   <script src="_static/language_data.js" type="text/javascript">
#   </script>
# ...

# %%
soup.find('div')
# Out:
# <div class="wy-grid-for-nav">
# <nav class="wy-nav-side" data-toggle="wy-nav-shift">
# <div class="wy-side-scroll">
# <div class="wy-side-nav-search">
# <a class="icon icon-home" href="#"> Beautiful Soup
#
#
#
#           </a>
# <div class="version">
#                 latest
#               </div>
# <div role="search">
# <form action="search.html" class="wy-form" id="rtd-search-form" method="get">
# <input name="q" placeholder="Search docs" type="text"/>
# <input name="check_keywords" type="hidden" value="yes"/>
# <input name="area" type="hidden" value="default"/>
# </form>
# </div>
# </div>
# <div aria-label="main navigation" class="wy-menu wy-menu-vertical" data-spy="affix" role="navigation">
# <!-- Local TOC -->
# <div class="local-toc"><ul>
# <li><a class="reference internal" href="#">Beautiful Soup Documentation</a><ul>
# <li><a class="reference internal" href="#getting-help">Getting help</a></li>
# </ul>
# </li>
# ...

# %%
print(len(soup.find_all('div')))
print(len(soup.find_all('p')))
print(len(soup.find_all('h1')))
print(len(soup.find_all('h2')))
print(len(soup.find_all('span')))
print(len(soup.find_all('col')))
print(len(soup.find_all('tr')))
print(len(soup.find_all('td')))
print(len(soup.find_all('li')))
# Out:
# 509
# 363
# 18
# 51
# 4891
# 4
# 5
# 20
# 172

# %%
[len(div) for div in soup.find_all('div')[:3]]
# Out:
# [5, 5, 7]

# %%
#[len(div) for div in soup.find_all('div')]

# %%
soup.find('div').text
# Out:
# '\n\n\n\n Beautiful Soup\n          \n\n          \n          \n\n                latest\n              \n\n\n\n\n\n\n\n\n\n\n\nBeautiful Soup Documentation\nGetting help\n\n\nQuick Start\nInstalling Beautiful Soup\nProblems after installation\nInstalling a parser\n\n\nMaking the soup\nKinds of objects\nTag\nName\nAttributes\nMulti-valued attributes\n\n\n\n\nNavigableString\nBeautifulSoup\nComments and other special strings\n\n\nNavigating the tree\nGoing down\nNavigating using tag names\n.contents and .children\n.descendants\n.string\n.strings and stripped_strings\n\n\nGoing up\n.parent\n.parents\n\n\nGoing sideways\n.next_sibling and .previous_sibling\n.next_siblings and .previous_siblings\n\n\nGoing back and forth\n.next_element and .previous_element\n.next_elements and .previous_elements\n\n\n\n\nSearching the tree\nKinds of filters\nA string\nA regular expression\nA list\nTrue\nA function\n\n\nfind_all()\nThe name argument\nThe keyword arguments\nSearching by CSS class\nThe stri
# ...

# %%
soup.find('div',{'class':'section','id':'making-the-soup'}).text.strip()
# Out:
# 'Making the soupÂ¶\nTo parse a document, pass it into the BeautifulSoup\nconstructor. You can pass in a string or an open filehandle:\nfrom bs4 import BeautifulSoup\n\nwith open("index.html") as fp:\n    soup = BeautifulSoup(fp)\n\nsoup = BeautifulSoup("<html>data</html>")\n\n\nFirst, the document is converted to Unicode, and HTML entities are\nconverted to Unicode characters:\nBeautifulSoup("Sacr&eacute; bleu!")\n<html><head></head><body>SacrÃ© bleu!</body></html>\n\n\nBeautiful Soup then parses the document using the best available\nparser. It will use an HTML parser unless you specifically tell it to\nuse an XML parser. (See Parsing XML.)'

# %%
url="http://shop.oreilly.com/category/browse-subjects/" + \
"data.do?sortby=publicationDate&page="
print(requests.get(url))
page=requests.get(url)
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.text,'html')
#print(soup.prettify())

# %%
tds = soup.find_all('td', 'class':'thumbtext')
print(len(tds))
# Out:
#   Cell In[480], line 1
#     tds = soup.find_all('td', 'class':'thumbtext')
#                                      ^
# SyntaxError: invalid syntax

# %%
def is_video(td):
    """it's a video if it has exactly one pricelabel, and if
    the stripped text inside that pricelabel starts with 'Video'"""
    pricelabels = td('span', 'pricelabel')
    return (len(pricelabels) == 1 and
        pricelabels[0].text.strip().startswith("Video"))

print (len([td for td in tds if not is_video(td)]))
# Out:
# 0

# %%
def book_info(td):
    """given a BeautifulSoup <td> Tag representing a book,
    extract the book's details and return a dict"""
    title = td.find("div", "thumbheader").a.text
    by_author = td.find('div', 'AuthorName').text
    authors = [x.strip() for x in re.sub("^By ", "", by_author).split(",")]
    isbn_link = td.find("div", "thumbheader").a.get("href")
    isbn = re.match("/product/(.*)\.do", isbn_link).groups()[0]
    date = td.find("span", "directorydate").text.strip()
    return {
    "title" : title,
    "authors" : authors,
    "isbn" : isbn,
    "date" : date
    }

# %%
books = []
NUM_PAGES = 15
for page_num in range(1, NUM_PAGES + 1):
    print("souping page", page_num, ",", len(books), " found so far")
    url = url + str(page_num)
    soup = BeautifulSoup(requests.get(url).text)
    for td in soup('td', 'thumbtext'):
        if not is_video(td):
            books.append(book_info(td))
# Out:
# souping page 1 , 0  found so far
# souping page 2 , 0  found so far
# souping page 3 , 0  found so far
# souping page 4 , 0  found so far
# souping page 5 , 0  found so far
# souping page 6 , 0  found so far
# souping page 7 , 0  found so far
# souping page 8 , 0  found so far
# souping page 9 , 0  found so far
# souping page 10 , 0  found so far
# souping page 11 , 0  found so far
# souping page 12 , 0  found so far
# souping page 13 , 0  found so far
# souping page 14 , 0  found so far
# souping page 15 , 0  found so far

# %%
def get_year(book):
    """book["date"] looks like 'November 2014' so we need to
    split on the space and then take the second piece"""
    return int(book["date"].split()[1])

# %%
from collections import Counter

# %%
year_counts = Counter(get_year(book) for book in books
                      if get_year(book) <= 2014)

# %%
year_counts
# Out:
# Counter()

# %%
import matplotlib.pyplot as plt
years = sorted(year_counts)
book_counts = [year_counts[year] for year in years]
plt.plot(years, book_counts)
plt.ylabel("# of data books")
plt.title("Data is Big!")
plt.show()

# %%
a class="bar-link has-inner-focus" data-linktype="absolute-path" href="/en-us/digital-contact-center-platform/"

# %%
soup.find('a',{'class':'bar-link has-inner-focus','href':'/en-us/digital-contact-center-platform/'}).text
# Out:
# '\n\t\t\t\t\t\t\tDigital Contact Center Platform\n\t\t\t\t\t\t'

# %%
soup.find('div',{'class':'margin-top-lg'})
# Out:
# '\n\n\n\n\t\t\t\t\t\t\t.net\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\t.net maui\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tadaptive cards\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tasp.net core\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tazure\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tbiztalk server\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tc++\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tc#\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tdax\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tdigital contact center platform\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tdynamics 365\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tdynamics 365 business central\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tdynamics 365 commerce\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tdynamics 365 customer insights\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tdynamics 365 customer service\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tdynamics 365 field service\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tdynamics 365 finance\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tdynamics 365 guides\n\t\t\t\t\t\t\n\n\n\n\t\t\t\t\t\t\tdynamics 365 human resources\n\t\t\t\t\t\t\n
# ...

# %%
[i for i in soup.find('div',{'class':'margin-top-lg'})]
# Out:
# ['\n',
#  <ul class="has-three-text-columns">
#  <li class="has-three-text-columns-list-items">
#  <a class="bar-link has-inner-focus" data-linktype="absolute-path" href="/en-us/dotnet/">
#  							.NET
#  						</a>
#  </li>
#  <li class="has-three-text-columns-list-items">
#  <a class="bar-link has-inner-focus" data-linktype="absolute-path" href="/en-us/dotnet/maui/">
#  							.NET MAUI
#  						</a>
#  </li>
#  <li class="has-three-text-columns-list-items">
#  <a class="bar-link has-inner-focus" data-linktype="absolute-path" href="/en-us/adaptive-cards/">
#  							Adaptive Cards
#  						</a>
#  </li>
#  <li class="has-three-text-columns-list-items">
#  <a class="bar-link has-inner-focus" data-linktype="absolute-path" href="/en-us/aspnet/core/">
#  							ASP.NET Core
#  						</a>
#  </li>
#  <li class="has-three-text-columns-list-items">
#  <a class="bar-link has-inner-focus" data-linktype="absolute-path" href="/en-us/azure/">
#  							Azure
#  						</a>
#  </li>
# ...
